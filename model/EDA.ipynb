# %% [markdown]
# **Checking API data**

# %%
import openmeteo_requests
import numpy as np
import requests_cache
import pandas as pd
from retry_requests import retry

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# %%
# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://archive-api.open-meteo.com/v1/archive"
params = {
	"latitude": [21.427222, 22.335, 23.763889, 22.71],
	"longitude": [92.005, 91.8325, 90.388889, 90.363],
	"start_date": ["2018-04-28","2018-05-01", "2018-05-01", "2018-05-01"],       #actual start date: 04-29 -> 2 days later
	"end_date": ["2018-05-02","2018-05-02", "2018-05-02", "2018-05-02"],         #actual end date: 04-30
	"daily": ["weather_code", "temperature_2m_max", "temperature_2m_min", "temperature_2m_mean", "precipitation_sum", "rain_sum", "wind_speed_10m_max", "wind_gusts_10m_max", "wind_direction_10m_dominant", "shortwave_radiation_sum"],
	"timezone": ["Asia/Dhaka", "Asia/Dhaka", "Asia/Dhaka", "Asia/Dhaka"],
	"elevation": ["NaN", "NaN", "NaN", "NaN"]
}
responses = openmeteo.weather_api(url, params=params)

# %%
# Process first location. Add a for-loop for multiple locations or weather models
response = responses[1]
print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
print(f"Elevation {response.Elevation()} m asl")
print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")
print(f"response length {len(responses)}")
print(f" response: {response}")
# Out:
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# response length 4
#  response: <openmeteo_sdk.WeatherApiResponse.WeatherApiResponse object at 0x000001864B6DFD00>

# %%
# Process daily data. The order of variables needs to be the same as requested.
daily = response.Daily()
daily_weather_code = daily.Variables(0).ValuesAsNumpy()
daily_temperature_2m_max = daily.Variables(1).ValuesAsNumpy()
daily_temperature_2m_min = daily.Variables(2).ValuesAsNumpy()
daily_temperature_2m_mean = daily.Variables(3).ValuesAsNumpy()
daily_precipitation_sum = daily.Variables(4).ValuesAsNumpy()
daily_rain_sum = daily.Variables(5).ValuesAsNumpy()
daily_wind_speed_10m_max = daily.Variables(6).ValuesAsNumpy()
daily_wind_gusts_10m_max = daily.Variables(7).ValuesAsNumpy()
daily_wind_direction_10m_dominant = daily.Variables(8).ValuesAsNumpy()
daily_shortwave_radiation_sum = daily.Variables(9).ValuesAsNumpy()

# %%
daily_data = {"date": pd.date_range(
	start = pd.to_datetime(daily.Time(), unit = "s", utc = True),
	end = pd.to_datetime(daily.TimeEnd(), unit = "s", utc = True),
	freq = pd.Timedelta(seconds = daily.Interval()),
	inclusive = "left"
)}
daily_data["weather_code"] =  daily_weather_code
daily_data["temperature_2m_max"] = daily_temperature_2m_max
daily_data["temperature_2m_min"] = daily_temperature_2m_min
daily_data["temperature_2m_mean"] = daily_temperature_2m_mean
daily_data["precipitation_sum"] = daily_precipitation_sum
daily_data["rain_sum"] = daily_rain_sum
daily_data["wind_speed_10m_max"] = daily_wind_speed_10m_max
daily_data["wind_gusts_10m_max"] = daily_wind_gusts_10m_max
daily_data["wind_direction_10m_dominant"] = daily_wind_direction_10m_dominant
daily_data["shortwave_radiation_sum"] = daily_shortwave_radiation_sum
print(daily_data)
# Out:
# {'date': DatetimeIndex(['2018-04-30 18:00:00+00:00', '2018-05-01 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'weather_code': array([63., 63.], dtype=float32), 'temperature_2m_max': array([30.65, 31.35], dtype=float32), 'temperature_2m_min': array([22.85, 22.45], dtype=float32), 'temperature_2m_mean': array([26.616669, 27.295832], dtype=float32), 'precipitation_sum': array([8.1, 4.4], dtype=float32), 'rain_sum': array([8.1, 4.4], dtype=float32), 'wind_speed_10m_max': array([13.783817, 16.575644], dtype=float32), 'wind_gusts_10m_max': array([32.760002, 37.079998], dtype=float32), 'wind_direction_10m_dominant': array([162.22856, 205.59842], dtype=float32), 'shortwave_radiation_sum': array([19.68, 23.98], dtype=float32)}

# %%
daily_dataframe = pd.DataFrame(data = daily_data)
print(daily_dataframe)
# Out:
#                        date  weather_code  temperature_2m_max  \
# 0 2018-04-30 18:00:00+00:00          63.0           30.299999
# 1 2018-05-01 18:00:00+00:00           1.0           30.350000
#
#    temperature_2m_min  temperature_2m_mean  precipitation_sum  rain_sum  \
# 0           24.400000            27.456247                6.5       6.5
# 1           24.549999            27.554167                0.0       0.0
#
#    wind_speed_10m_max  wind_gusts_10m_max  wind_direction_10m_dominant  \
# 0           18.837322           39.599998                   219.876755
# 1           19.642281           38.880001                   221.061829
#
#    shortwave_radiation_sum
# 0                    21.08
# 1                    23.98

# %% [markdown]
# **Loading Disaster Data CSV and cleaning the data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('disaster.csv')
df.head()
# Out:
#    Year   Seq Glide Disaster Group Disaster Subgroup      Disaster Type  \
# 0  1900  9002   NaN        Natural    Climatological            Drought
# 1  1900  9001   NaN        Natural    Climatological            Drought
# 2  1902    12   NaN        Natural       Geophysical         Earthquake
# 3  1902     3   NaN        Natural       Geophysical  Volcanic activity
# 4  1902    10   NaN        Natural       Geophysical  Volcanic activity
#
#   Disaster Subtype Disaster Subsubtype   Event Name     Country  ...  \
# 0          Drought                 NaN          NaN  Cabo Verde  ...
# 1          Drought                 NaN          NaN       India  ...
# 2  Ground movement                 NaN          NaN   Guatemala  ...
# 3         Ash fall                 NaN  Santa Maria   Guatemala  ...
# 4         Ash fall                 NaN  Santa Maria   Guatemala  ...
#
#   No Affected No Homeless Total Affected Insured Damages ('000 US$)  \
# 0         NaN         NaN            NaN                        NaN
# 1         NaN         NaN            NaN                        NaN
# 2         NaN         NaN            NaN                        NaN
# 3         NaN         NaN            NaN                        NaN
# 4         NaN         NaN            NaN                        NaN
#
#   Total Damages ('000 US$)       CPI Adm Level Admin1 Code Admin2 Code  \
# 0                      NaN  3.221647       NaN         NaN         NaN
# 1                      NaN  3.221647       NaN         NaN         NaN
# 2                  25000.0  3.350513       NaN         NaN         NaN
# 3                      NaN  3.350513       NaN         NaN         NaN
# 4                      NaN  3.350513       NaN         NaN         NaN
#
#   Geo Locations
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 45 columns]

# %%
n_df = df[df['Country']=='Bangladesh']
print(n_df)
# Out:
#        Year  Seq           Glide Disaster Group Disaster Subgroup  \
# 7      1904    3             NaN        Natural    Meteorological
# 18     1909   10             NaN        Natural    Meteorological
# 19     1909   13             NaN        Natural    Meteorological
# 32     1911    4             NaN        Natural    Meteorological
# 47     1918    1             NaN        Natural        Biological
# ...     ...  ...             ...            ...               ...
# 15105  2019  655             NaN        Natural    Meteorological
# 15150  2020  323  FL-2020-000166        Natural      Hydrological
# 15191  2020  211   TC-2020-00135        Natural    Meteorological
# 15243  2021  455             NaN        Natural      Hydrological
# 15288  2021  295  TC-2021-000058        Natural    Meteorological
#
#               Disaster Type  Disaster Subtype Disaster Subsubtype  \
# 7                     Storm  Tropical cyclone                 NaN
# 18                    Storm  Tropical cyclone                 NaN
# 19                    Storm  Tropical cyclone                 NaN
# 32                    Storm  Tropical cyclone                 NaN
# 47                 Epidemic     Viral disease                 NaN
# ...                     ...               ...                 ...
# 15105  Extreme temperature          Cold wave                 NaN
# 15150                 Flood               NaN                 NaN
# 15191                 Storm  Tropical cyclone                 NaN
# 15243                 Flood               NaN                 NaN
# 15288                 Storm  Tropical cyclone                 NaN
#
#              Event Name     Country  ... No Affected No Homeless  \
# 7                   NaN  Bangladesh  ...         NaN         NaN
# 18                  NaN  Bangladesh  ...         NaN         NaN
# 19                  NaN  Bangladesh  ...         NaN         NaN
# 32                  NaN  Bangladesh  ...         NaN         NaN
# 47            Influenza  Bangladesh  ...         NaN         NaN
# ...                 ...         ...  ...         ...         ...
# 15105               NaN  Bangladesh  ...         NaN         NaN
# 15150               NaN  Bangladesh  ...   5448271.0         NaN
# 15191  Cyclone 'Amphan'  Bangladesh  ...   2600000.0         NaN
# 15243               NaN  Bangladesh  ...    268744.0         NaN
# 15288    Cyclone 'Yaas'  Bangladesh  ...   1300000.0         NaN
#
#       Total Affected Insured Damages ('000 US$) Total Damages ('000 US$)  \
# 7                NaN                        NaN                      NaN
# 18               NaN                        NaN                      NaN
# 19               NaN                        NaN                      NaN
# 32               NaN                        NaN                      NaN
# 47               NaN                        NaN                      NaN
# ...              ...                        ...                      ...
# 15105         4500.0                        NaN                      NaN
# 15150      5448271.0                        NaN                 500000.0
# 15191      2600000.0                        NaN                1500000.0
# 15243       268744.0                        NaN                      NaN
# 15288      1300000.0                        NaN                      NaN
#
#               CPI Adm Level Admin1 Code  \
# 7        3.479379       NaN         NaN
# 18       3.479379       NaN         NaN
# 19       3.479379       NaN         NaN
# 32       3.608245       NaN         NaN
# 47       5.824738       NaN         NaN
# ...           ...       ...         ...
# 15105   98.781448         2         NaN
# 15150  100.000000       1;2         580
# 15191  100.000000       1;2         578
# 15243         NaN       NaN         NaN
# 15288         NaN         2         NaN
#
#                                              Admin2 Code  \
# 7                                                    NaN
# 18                                                   NaN
# 19                                                   NaN
# 32                                                   NaN
# 47                                                   NaN
# ...                                                  ...
# 15105       5796;5797;5806;5809;5811;5814;5815;5816;5817
# 15150  5779;5782;5785;5790;5791;5793;5794;5800;5805;5...
# 15191                                               5772
# 15243                                                NaN
# 15288                 5761;5763;5764;5765;5766;5795;5804
#
#                                            Geo Locations
# 7                                                    NaN
# 18                                                   NaN
# 19                                                   NaN
# 32                                                   NaN
# 47                                                   NaN
# ...                                                  ...
# 15105  Chuadanga, Dinajpur, Jessore, Kurigram, Naogao...
# 15150  Sylhet (Adm1). Bogra, Faridpur, Gaibandha, Jam...
# 15191                Khulna (Adm1). Cox's Bazar (Adm2).
# 15243                                                NaN
# 15288  Bagerhat, Barguna, Bhola, Jhalokati, Patuakhal...
#
# [356 rows x 45 columns]

# %%
n_df.describe()
# Out:
#               Year          Seq  Aid Contribution  Dis Mag Value   Start Year  \
# count   356.000000   356.000000         19.000000     110.000000   356.000000
# mean   1991.755618   416.643258      34894.368421    7083.027273  1991.758427
# std      20.166891  1255.896241      72407.026470   17373.800454    20.165598
# min    1904.000000     1.000000        161.000000      -7.000000  1904.000000
# 25%    1983.750000    76.000000        534.500000      57.000000  1983.750000
# 50%    1995.000000   190.000000       1551.000000     120.000000  1995.000000
# 75%    2005.000000   373.000000       8828.500000     556.250000  2005.000000
# max    2021.000000  9350.000000     234100.000000   91120.000000  2021.000000
#
#        Start Month   Start Day     End Year   End Month     End Day  \
# count   353.000000  274.000000   356.000000  348.000000  273.000000
# mean      6.317280   16.094891  1991.775281    6.290230   16.168498
# std       2.817591    8.888716    20.175988    2.861695    8.871271
# min       1.000000    1.000000  1904.000000    1.000000    1.000000
# 25%       4.000000    9.000000  1983.750000    4.000000    9.000000
# 50%       6.000000   15.500000  1995.000000    6.000000   15.000000
# 75%       8.000000   24.000000  2005.000000    8.250000   23.000000
# max      12.000000   31.000000  2021.000000   12.000000   31.000000
#
#        Total Deaths     No Injured   No Affected   No Homeless  \
# count  3.180000e+02     127.000000  1.800000e+02  6.200000e+01
# mean   9.415057e+03    8432.661417  2.493596e+06  2.328537e+05
# std    1.102418e+05   55345.775663  6.558631e+06  7.264074e+05
# min    1.000000e+00       2.000000  1.200000e+01  2.250000e+02
# 25%    1.500000e+01      70.500000  1.884375e+04  7.575000e+03
# 50%    4.100000e+01     200.000000  1.692300e+05  2.447150e+04
# 75%    1.657500e+02     500.000000  1.498934e+06  1.000000e+05
# max    1.900000e+06  600000.000000  4.500000e+07  5.000000e+06
#
#        Total Affected  Insured Damages ('000 US$)  Total Damages ('000 US$)  \
# count    2.650000e+02                         1.0              5.300000e+01
# mean     1.752284e+06                     80000.0              4.130861e+05
# std      5.637644e+06                         NaN              7.958455e+05
# min      6.000000e+00                     80000.0              2.010000e+02
# 25%      1.500000e+03                     80000.0              1.400000e+04
# 50%      4.020000e+04                     80000.0              1.000000e+05
# 75%      5.000000e+05                     80000.0              5.000000e+05
# max      4.500000e+07                     80000.0              4.300000e+06
#
#               CPI
# count  354.000000
# mean    55.593900
# std     25.968809
# min      3.479379
# 25%     38.897403
# 50%     58.878183
# 75%     75.457200
# max    100.000000

# %% [markdown]
# We'll be dropping rows relating to earthquake data as well as earthquakes have no relation to weather data

# %%
n_df['Disaster Subgroup'].unique()
# Out:
# array(['Meteorological', 'Biological', 'Climatological', 'Hydrological',
#        'Geophysical'], dtype=object)

# %%
nn_df = n_df[n_df['Disaster Subgroup']!='Geophysical']   #geophysical incidents are earthquakes
print(nn_df)
# Out:
#        Year  Seq           Glide Disaster Group Disaster Subgroup  \
# 7      1904    3             NaN        Natural    Meteorological
# 18     1909   10             NaN        Natural    Meteorological
# 19     1909   13             NaN        Natural    Meteorological
# 32     1911    4             NaN        Natural    Meteorological
# 47     1918    1             NaN        Natural        Biological
# ...     ...  ...             ...            ...               ...
# 15105  2019  655             NaN        Natural    Meteorological
# 15150  2020  323  FL-2020-000166        Natural      Hydrological
# 15191  2020  211   TC-2020-00135        Natural    Meteorological
# 15243  2021  455             NaN        Natural      Hydrological
# 15288  2021  295  TC-2021-000058        Natural    Meteorological
#
#               Disaster Type  Disaster Subtype Disaster Subsubtype  \
# 7                     Storm  Tropical cyclone                 NaN
# 18                    Storm  Tropical cyclone                 NaN
# 19                    Storm  Tropical cyclone                 NaN
# 32                    Storm  Tropical cyclone                 NaN
# 47                 Epidemic     Viral disease                 NaN
# ...                     ...               ...                 ...
# 15105  Extreme temperature          Cold wave                 NaN
# 15150                 Flood               NaN                 NaN
# 15191                 Storm  Tropical cyclone                 NaN
# 15243                 Flood               NaN                 NaN
# 15288                 Storm  Tropical cyclone                 NaN
#
#              Event Name     Country  ... No Affected No Homeless  \
# 7                   NaN  Bangladesh  ...         NaN         NaN
# 18                  NaN  Bangladesh  ...         NaN         NaN
# 19                  NaN  Bangladesh  ...         NaN         NaN
# 32                  NaN  Bangladesh  ...         NaN         NaN
# 47            Influenza  Bangladesh  ...         NaN         NaN
# ...                 ...         ...  ...         ...         ...
# 15105               NaN  Bangladesh  ...         NaN         NaN
# 15150               NaN  Bangladesh  ...   5448271.0         NaN
# 15191  Cyclone 'Amphan'  Bangladesh  ...   2600000.0         NaN
# 15243               NaN  Bangladesh  ...    268744.0         NaN
# 15288    Cyclone 'Yaas'  Bangladesh  ...   1300000.0         NaN
#
#       Total Affected Insured Damages ('000 US$) Total Damages ('000 US$)  \
# 7                NaN                        NaN                      NaN
# 18               NaN                        NaN                      NaN
# 19               NaN                        NaN                      NaN
# 32               NaN                        NaN                      NaN
# 47               NaN                        NaN                      NaN
# ...              ...                        ...                      ...
# 15105         4500.0                        NaN                      NaN
# 15150      5448271.0                        NaN                 500000.0
# 15191      2600000.0                        NaN                1500000.0
# 15243       268744.0                        NaN                      NaN
# 15288      1300000.0                        NaN                      NaN
#
#               CPI Adm Level Admin1 Code  \
# 7        3.479379       NaN         NaN
# 18       3.479379       NaN         NaN
# 19       3.479379       NaN         NaN
# 32       3.608245       NaN         NaN
# 47       5.824738       NaN         NaN
# ...           ...       ...         ...
# 15105   98.781448         2         NaN
# 15150  100.000000       1;2         580
# 15191  100.000000       1;2         578
# 15243         NaN       NaN         NaN
# 15288         NaN         2         NaN
#
#                                              Admin2 Code  \
# 7                                                    NaN
# 18                                                   NaN
# 19                                                   NaN
# 32                                                   NaN
# 47                                                   NaN
# ...                                                  ...
# 15105       5796;5797;5806;5809;5811;5814;5815;5816;5817
# 15150  5779;5782;5785;5790;5791;5793;5794;5800;5805;5...
# 15191                                               5772
# 15243                                                NaN
# 15288                 5761;5763;5764;5765;5766;5795;5804
#
#                                            Geo Locations
# 7                                                    NaN
# 18                                                   NaN
# 19                                                   NaN
# 32                                                   NaN
# 47                                                   NaN
# ...                                                  ...
# 15105  Chuadanga, Dinajpur, Jessore, Kurigram, Naogao...
# 15150  Sylhet (Adm1). Bogra, Faridpur, Gaibandha, Jam...
# 15191                Khulna (Adm1). Cox's Bazar (Adm2).
# 15243                                                NaN
# 15288  Bagerhat, Barguna, Bhola, Jhalokati, Patuakhal...
#
# [347 rows x 45 columns]

# %% [markdown]
# The api we're using also only has data available from 1970 onwards, so we'll be filtering our data accordingly

# %%
nnn_df = nn_df[nn_df['Year'] > 1939]
print(nnn_df)
# Out:
#        Year   Seq           Glide Disaster Group Disaster Subgroup  \
# 143    1941     3             NaN        Natural    Meteorological
# 146    1942     8             NaN        Natural    Meteorological
# 152    1943  9002             NaN        Natural    Climatological
# 170    1947    12             NaN        Natural    Meteorological
# 171    1947  9005             NaN        Natural    Climatological
# ...     ...   ...             ...            ...               ...
# 15105  2019   655             NaN        Natural    Meteorological
# 15150  2020   323  FL-2020-000166        Natural      Hydrological
# 15191  2020   211   TC-2020-00135        Natural    Meteorological
# 15243  2021   455             NaN        Natural      Hydrological
# 15288  2021   295  TC-2021-000058        Natural    Meteorological
#
#               Disaster Type  Disaster Subtype Disaster Subsubtype  \
# 143                   Storm  Tropical cyclone                 NaN
# 146                   Storm  Tropical cyclone                 NaN
# 152                 Drought           Drought                 NaN
# 170                   Storm  Tropical cyclone                 NaN
# 171                 Drought           Drought                 NaN
# ...                     ...               ...                 ...
# 15105  Extreme temperature          Cold wave                 NaN
# 15150                 Flood               NaN                 NaN
# 15191                 Storm  Tropical cyclone                 NaN
# 15243                 Flood               NaN                 NaN
# 15288                 Storm  Tropical cyclone                 NaN
#
#              Event Name     Country  ... No Affected No Homeless  \
# 143                 NaN  Bangladesh  ...         NaN         NaN
# 146                 NaN  Bangladesh  ...         NaN         NaN
# 152                 NaN  Bangladesh  ...         NaN         NaN
# 170                 NaN  Bangladesh  ...         NaN         NaN
# 171                 NaN  Bangladesh  ...         NaN         NaN
# ...                 ...         ...  ...         ...         ...
# 15105               NaN  Bangladesh  ...         NaN         NaN
# 15150               NaN  Bangladesh  ...   5448271.0         NaN
# 15191  Cyclone 'Amphan'  Bangladesh  ...   2600000.0         NaN
# 15243               NaN  Bangladesh  ...    268744.0         NaN
# 15288    Cyclone 'Yaas'  Bangladesh  ...   1300000.0         NaN
#
#       Total Affected Insured Damages ('000 US$) Total Damages ('000 US$)  \
# 143              NaN                        NaN                      NaN
# 146              NaN                        NaN                      NaN
# 152              NaN                        NaN                      NaN
# 170              NaN                        NaN                      NaN
# 171              NaN                        NaN                      NaN
# ...              ...                        ...                      ...
# 15105         4500.0                        NaN                      NaN
# 15150      5448271.0                        NaN                 500000.0
# 15191      2600000.0                        NaN                1500000.0
# 15243       268744.0                        NaN                      NaN
# 15288      1300000.0                        NaN                      NaN
#
#               CPI Adm Level Admin1 Code  \
# 143      5.695872       NaN         NaN
# 146      6.327315       NaN         NaN
# 152      6.701026       NaN         NaN
# 170      8.646901       NaN         NaN
# 171      8.646901       NaN         NaN
# ...           ...       ...         ...
# 15105   98.781448         2         NaN
# 15150  100.000000       1;2         580
# 15191  100.000000       1;2         578
# 15243         NaN       NaN         NaN
# 15288         NaN         2         NaN
#
#                                              Admin2 Code  \
# 143                                                  NaN
# 146                                                  NaN
# 152                                                  NaN
# 170                                                  NaN
# 171                                                  NaN
# ...                                                  ...
# 15105       5796;5797;5806;5809;5811;5814;5815;5816;5817
# 15150  5779;5782;5785;5790;5791;5793;5794;5800;5805;5...
# 15191                                               5772
# 15243                                                NaN
# 15288                 5761;5763;5764;5765;5766;5795;5804
#
#                                            Geo Locations
# 143                                                  NaN
# 146                                                  NaN
# 152                                                  NaN
# 170                                                  NaN
# 171                                                  NaN
# ...                                                  ...
# 15105  Chuadanga, Dinajpur, Jessore, Kurigram, Naogao...
# 15150  Sylhet (Adm1). Bogra, Faridpur, Gaibandha, Jam...
# 15191                Khulna (Adm1). Cox's Bazar (Adm2).
# 15243                                                NaN
# 15288  Bagerhat, Barguna, Bhola, Jhalokati, Patuakhal...
#
# [337 rows x 45 columns]

# %% [markdown]
# We'll be dropping rows where there is no starting and ending date, as these are the parameters we'll be using to fetch weather data

# %%
df_cleaned = nnn_df.dropna(subset=['Start Day', 'Start Month', 'End Day', 'End Month' ])
null_checker = df_cleaned.apply(lambda x: sum(x.isnull())).to_frame(name='count')
print(null_checker)
# Out:
#                             count
# Year                            0
# Seq                             0
# Glide                         231
# Disaster Group                  0
# Disaster Subgroup               0
# Disaster Type                   0
# Disaster Subtype               66
# Disaster Subsubtype           220
# Event Name                    232
# Country                         0
# ISO                             0
# Region                          0
# Continent                       0
# Location                       17
# Origin                        208
# Associated Dis                215
# Associated Dis2               251
# OFDA Response                 242
# Appeal                        208
# Declaration                   210
# Aid Contribution              241
# Dis Mag Value                 170
# Dis Mag Scale                   6
# Latitude                      244
# Longitude                     244
# Local Time                    256
# River Basin                   227
# Start Year                      0
# Start Month                     0
# Start Day                       0
# End Year                        0
# End Month                       0
# End Day                         0
# Total Deaths                   17
# No Injured                    142
# No Affected                   121
# No Homeless                   201
# Total Affected                 47
# Insured Damages ('000 US$)    256
# Total Damages ('000 US$)      215
# CPI                             2
# Adm Level                     149
# Admin1 Code                   239
# Admin2 Code                   158
# Geo Locations                 149

# %% [markdown]
# As we can see, all the null values from start and end month have been removed.Disaster types also didn't have any null values in the first place. Now we'll be iterating over these values to collect weather related data from these dates

# %%
def get_weather_data(start_date, end_date):
    cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
    retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
    openmeteo = openmeteo_requests.Client(session = retry_session)

    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
	    "latitude": 22.335,
	    "longitude": 91.8325,
	    "start_date": start_date,
	    "end_date": end_date,
	    "daily": ["weather_code", "temperature_2m_max", "temperature_2m_min", "temperature_2m_mean", "precipitation_sum", "rain_sum", "wind_speed_10m_max", "wind_gusts_10m_max", "wind_direction_10m_dominant", "shortwave_radiation_sum"],
	    "timezone": "Asia/Dhaka",
	    "elevation": "NaN"
    }
    responses = openmeteo.weather_api(url, params=params)


    response = responses[0]
    print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
    print(f"Elevation {response.Elevation()} m asl")
    print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
    print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

    daily = response.Daily()
    daily_weather_code = daily.Variables(0).ValuesAsNumpy()
    daily_temperature_2m_max = daily.Variables(1).ValuesAsNumpy()
    daily_temperature_2m_min = daily.Variables(2).ValuesAsNumpy()
    daily_temperature_2m_mean = daily.Variables(3).ValuesAsNumpy()
    daily_precipitation_sum = daily.Variables(4).ValuesAsNumpy()
    daily_rain_sum = daily.Variables(5).ValuesAsNumpy()
    daily_wind_speed_10m_max = daily.Variables(6).ValuesAsNumpy()
    daily_wind_gusts_10m_max = daily.Variables(7).ValuesAsNumpy()
    daily_wind_direction_10m_dominant = daily.Variables(8).ValuesAsNumpy()
    daily_shortwave_radiation_sum = daily.Variables(9).ValuesAsNumpy()

    daily_data = {"date": pd.date_range(
	    start = pd.to_datetime(daily.Time(), unit = "s", utc = True),
	    end = pd.to_datetime(daily.TimeEnd(), unit = "s", utc = True),
	    freq = pd.Timedelta(seconds = daily.Interval()),
	    inclusive = "left"
    )}
    daily_data["start_date"] = start_date
    daily_data["end_date"] = end_date
    daily_data["weather_code"] = np.average(daily_weather_code)
    daily_data["temperature_2m_max"] = np.average(daily_temperature_2m_max)
    daily_data["temperature_2m_min"] = np.average(daily_temperature_2m_min)
    daily_data["temperature_2m_mean"] = np.average(daily_temperature_2m_mean)
    daily_data["precipitation_sum"] = np.average(daily_precipitation_sum)
    daily_data["rain_sum"] = np.average(daily_rain_sum)
    daily_data["wind_speed_10m_max"] = np.average(daily_wind_speed_10m_max)
    daily_data["wind_gusts_10m_max"] = np.average(daily_wind_gusts_10m_max)
    daily_data["wind_direction_10m_dominant"] = np.average(daily_wind_direction_10m_dominant)
    daily_data["shortwave_radiation_sum"] = np.average(daily_shortwave_radiation_sum)
    

    print(daily_data)
    return daily_data

# %%
date_list = []
days_in_month = [ 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31 ]

for index, row in df_cleaned.iterrows():
    
    st_day = int(row['Start Day'])
    st_mon = int(row['Start Month'])
    
    fin_day = int(row['End Day'])
    fin_mon = int(row['End Month'])
    
    #print(st_mon, st_day, " ", fin_mon, fin_day)
    
    if(st_day > days_in_month[st_mon-1]):
        st_day += (st_day % days_in_month[st_mon-1])
        st_mon+=1
        
    if(fin_day > days_in_month[fin_mon-1]):
        fin_day += (fin_day % days_in_month[fin_mon-1])
        fin_mon+=1
    
    start_date = (f"{int(row['Start Year']):04d}-{int(st_mon)  :02d}-{int(st_day):02d}")
    end_date = (f"{int(row['End Year']):04d}-{int(fin_mon):02d}-{int(fin_day):02d}")
    
    #print(start_date, end_date)
    results = get_weather_data(start_date, end_date)
    print(results)
    date_list.append(results)
    
print(date_list)
# Out:
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1941-05-20 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1941-05-21', 'end_date': '1941-05-21', 'weather_code': 51.0, 'temperature_2m_max': 29.55, 'temperature_2m_min': 26.8, 'temperature_2m_mean': 28.24375, 'precipitation_sum': 1.6000001, 'rain_sum': 1.6000001, 'wind_speed_10m_max': 13.32, 'wind_gusts_10m_max': 21.599998, 'wind_direction_10m_dominant': 260.71222, 'shortwave_radiation_sum': 24.21}
# {'date': DatetimeIndex(['1941-05-20 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1941-05-21', 'end_date': '1941-05-21', 'weather_code': 51.0, 'temperature_2m_max': 29.55, 'temperature_2m_min': 26.8, 'temperature_2m_mean': 28.24375, 'precipitation_sum': 1.6000001, 'rain_sum': 1.6000001, 'wind_speed_10m_max': 13.32, 'wind_gusts_10m_max': 21.599998, 'wind_direction_10m_dominant': 260.71222, 'shortwave_radiation_sum': 24.21}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1947-10-20 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1947-10-21', 'end_date': '1947-10-21', 'weather_code': 1.0, 'temperature_2m_max': 28.35, 'temperature_2m_min': 24.6, 'temperature_2m_mean': 26.481249, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 20.188908, 'wind_gusts_10m_max': 29.16, 'wind_direction_10m_dominant': 1.1133666, 'shortwave_radiation_sum': 20.72}
# {'date': DatetimeIndex(['1947-10-20 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1947-10-21', 'end_date': '1947-10-21', 'weather_code': 1.0, 'temperature_2m_max': 28.35, 'temperature_2m_min': 24.6, 'temperature_2m_mean': 26.481249, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 20.188908, 'wind_gusts_10m_max': 29.16, 'wind_direction_10m_dominant': 1.1133666, 'shortwave_radiation_sum': 20.72}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1958-10-19 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1958-10-20', 'end_date': '1958-10-20', 'weather_code': 51.0, 'temperature_2m_max': 29.55, 'temperature_2m_min': 24.1, 'temperature_2m_mean': 26.766668, 'precipitation_sum': 0.8, 'rain_sum': 0.8, 'wind_speed_10m_max': 9.83268, 'wind_gusts_10m_max': 15.119999, 'wind_direction_10m_dominant': 104.60445, 'shortwave_radiation_sum': 18.18}
# {'date': DatetimeIndex(['1958-10-19 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1958-10-20', 'end_date': '1958-10-20', 'weather_code': 51.0, 'temperature_2m_max': 29.55, 'temperature_2m_min': 24.1, 'temperature_2m_mean': 26.766668, 'precipitation_sum': 0.8, 'rain_sum': 0.8, 'wind_speed_10m_max': 9.83268, 'wind_gusts_10m_max': 15.119999, 'wind_direction_10m_dominant': 104.60445, 'shortwave_radiation_sum': 18.18}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1960-10-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1960-10-09', 'end_date': '1960-10-09', 'weather_code': 63.0, 'temperature_2m_max': 27.65, 'temperature_2m_min': 25.7, 'temperature_2m_mean': 26.587502, 'precipitation_sum': 44.4, 'rain_sum': 44.4, 'wind_speed_10m_max': 39.797504, 'wind_gusts_10m_max': 55.079998, 'wind_direction_10m_dominant': 342.63153, 'shortwave_radiation_sum': 6.32}
# {'date': DatetimeIndex(['1960-10-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1960-10-09', 'end_date': '1960-10-09', 'weather_code': 63.0, 'temperature_2m_max': 27.65, 'temperature_2m_min': 25.7, 'temperature_2m_mean': 26.587502, 'precipitation_sum': 44.4, 'rain_sum': 44.4, 'wind_speed_10m_max': 39.797504, 'wind_gusts_10m_max': 55.079998, 'wind_direction_10m_dominant': 342.63153, 'shortwave_radiation_sum': 6.32}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1960-10-29 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1960-10-30', 'end_date': '1960-10-30', 'weather_code': 61.0, 'temperature_2m_max': 28.9, 'temperature_2m_min': 23.25, 'temperature_2m_mean': 25.699999, 'precipitation_sum': 2.0, 'rain_sum': 2.0, 'wind_speed_10m_max': 15.745627, 'wind_gusts_10m_max': 20.880001, 'wind_direction_10m_dominant': 16.234982, 'shortwave_radiation_sum': 16.97}
# {'date': DatetimeIndex(['1960-10-29 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1960-10-30', 'end_date': '1960-10-30', 'weather_code': 61.0, 'temperature_2m_max': 28.9, 'temperature_2m_min': 23.25, 'temperature_2m_mean': 25.699999, 'precipitation_sum': 2.0, 'rain_sum': 2.0, 'wind_speed_10m_max': 15.745627, 'wind_gusts_10m_max': 20.880001, 'wind_direction_10m_dominant': 16.234982, 'shortwave_radiation_sum': 16.97}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1961-05-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1961-05-09', 'end_date': '1961-05-09', 'weather_code': 63.0, 'temperature_2m_max': 27.3, 'temperature_2m_min': 25.4, 'temperature_2m_mean': 26.370829, 'precipitation_sum': 44.8, 'rain_sum': 44.8, 'wind_speed_10m_max': 61.99217, 'wind_gusts_10m_max': 100.799995, 'wind_direction_10m_dominant': 282.09473, 'shortwave_radiation_sum': 9.13}
# {'date': DatetimeIndex(['1961-05-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1961-05-09', 'end_date': '1961-05-09', 'weather_code': 63.0, 'temperature_2m_max': 27.3, 'temperature_2m_min': 25.4, 'temperature_2m_mean': 26.370829, 'precipitation_sum': 44.8, 'rain_sum': 44.8, 'wind_speed_10m_max': 61.99217, 'wind_gusts_10m_max': 100.799995, 'wind_direction_10m_dominant': 282.09473, 'shortwave_radiation_sum': 9.13}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1961-05-29 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1961-05-30', 'end_date': '1961-05-30', 'weather_code': 65.0, 'temperature_2m_max': 29.45, 'temperature_2m_min': 26.35, 'temperature_2m_mean': 27.039583, 'precipitation_sum': 55.4, 'rain_sum': 55.4, 'wind_speed_10m_max': 32.86861, 'wind_gusts_10m_max': 54.36, 'wind_direction_10m_dominant': 169.65616, 'shortwave_radiation_sum': 3.5}
# {'date': DatetimeIndex(['1961-05-29 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1961-05-30', 'end_date': '1961-05-30', 'weather_code': 65.0, 'temperature_2m_max': 29.45, 'temperature_2m_min': 26.35, 'temperature_2m_mean': 27.039583, 'precipitation_sum': 55.4, 'rain_sum': 55.4, 'wind_speed_10m_max': 32.86861, 'wind_gusts_10m_max': 54.36, 'wind_direction_10m_dominant': 169.65616, 'shortwave_radiation_sum': 3.5}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1963-05-27 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1963-05-28', 'end_date': '1963-05-28', 'weather_code': 63.0, 'temperature_2m_max': 28.15, 'temperature_2m_min': 25.8, 'temperature_2m_mean': 26.727081, 'precipitation_sum': 37.6, 'rain_sum': 37.6, 'wind_speed_10m_max': 67.4008, 'wind_gusts_10m_max': 117.0, 'wind_direction_10m_dominant': 6.492796, 'shortwave_radiation_sum': 5.68}
# {'date': DatetimeIndex(['1963-05-27 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1963-05-28', 'end_date': '1963-05-28', 'weather_code': 63.0, 'temperature_2m_max': 28.15, 'temperature_2m_min': 25.8, 'temperature_2m_mean': 26.727081, 'precipitation_sum': 37.6, 'rain_sum': 37.6, 'wind_speed_10m_max': 67.4008, 'wind_gusts_10m_max': 117.0, 'wind_direction_10m_dominant': 6.492796, 'shortwave_radiation_sum': 5.68}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1964-04-11 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1964-04-12', 'end_date': '1964-04-12', 'weather_code': 51.0, 'temperature_2m_max': 31.15, 'temperature_2m_min': 27.05, 'temperature_2m_mean': 28.564583, 'precipitation_sum': 0.70000005, 'rain_sum': 0.70000005, 'wind_speed_10m_max': 31.433586, 'wind_gusts_10m_max': 49.32, 'wind_direction_10m_dominant': 273.46512, 'shortwave_radiation_sum': 23.46}
# {'date': DatetimeIndex(['1964-04-11 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1964-04-12', 'end_date': '1964-04-12', 'weather_code': 51.0, 'temperature_2m_max': 31.15, 'temperature_2m_min': 27.05, 'temperature_2m_mean': 28.564583, 'precipitation_sum': 0.70000005, 'rain_sum': 0.70000005, 'wind_speed_10m_max': 31.433586, 'wind_gusts_10m_max': 49.32, 'wind_direction_10m_dominant': 273.46512, 'shortwave_radiation_sum': 23.46}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1965-05-10 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1965-05-11', 'end_date': '1965-05-11', 'weather_code': 63.0, 'temperature_2m_max': 28.95, 'temperature_2m_min': 24.9, 'temperature_2m_mean': 25.993752, 'precipitation_sum': 37.499996, 'rain_sum': 37.499996, 'wind_speed_10m_max': 38.047756, 'wind_gusts_10m_max': 51.12, 'wind_direction_10m_dominant': 342.2702, 'shortwave_radiation_sum': 10.66}
# {'date': DatetimeIndex(['1965-05-10 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1965-05-11', 'end_date': '1965-05-11', 'weather_code': 63.0, 'temperature_2m_max': 28.95, 'temperature_2m_min': 24.9, 'temperature_2m_mean': 25.993752, 'precipitation_sum': 37.499996, 'rain_sum': 37.499996, 'wind_speed_10m_max': 38.047756, 'wind_gusts_10m_max': 51.12, 'wind_direction_10m_dominant': 342.2702, 'shortwave_radiation_sum': 10.66}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1965-12-14 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1965-12-15', 'end_date': '1965-12-15', 'weather_code': 65.0, 'temperature_2m_max': 23.3, 'temperature_2m_min': 21.75, 'temperature_2m_mean': 22.49375, 'precipitation_sum': 71.100006, 'rain_sum': 71.100006, 'wind_speed_10m_max': 40.896065, 'wind_gusts_10m_max': 68.4, 'wind_direction_10m_dominant': 95.12086, 'shortwave_radiation_sum': 7.12}
# {'date': DatetimeIndex(['1965-12-14 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1965-12-15', 'end_date': '1965-12-15', 'weather_code': 65.0, 'temperature_2m_max': 23.3, 'temperature_2m_min': 21.75, 'temperature_2m_mean': 22.49375, 'precipitation_sum': 71.100006, 'rain_sum': 71.100006, 'wind_speed_10m_max': 40.896065, 'wind_gusts_10m_max': 68.4, 'wind_direction_10m_dominant': 95.12086, 'shortwave_radiation_sum': 7.12}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1966-09-30 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1966-10-01', 'end_date': '1966-10-01', 'weather_code': 65.0, 'temperature_2m_max': 25.95, 'temperature_2m_min': 23.3, 'temperature_2m_mean': 24.779167, 'precipitation_sum': 77.0, 'rain_sum': 77.0, 'wind_speed_10m_max': 72.16181, 'wind_gusts_10m_max': 119.88, 'wind_direction_10m_dominant': 272.0682, 'shortwave_radiation_sum': 3.56}
# {'date': DatetimeIndex(['1966-09-30 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1966-10-01', 'end_date': '1966-10-01', 'weather_code': 65.0, 'temperature_2m_max': 25.95, 'temperature_2m_min': 23.3, 'temperature_2m_mean': 24.779167, 'precipitation_sum': 77.0, 'rain_sum': 77.0, 'wind_speed_10m_max': 72.16181, 'wind_gusts_10m_max': 119.88, 'wind_direction_10m_dominant': 272.0682, 'shortwave_radiation_sum': 3.56}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1967-05-01 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1967-05-02', 'end_date': '1967-05-02', 'weather_code': 65.0, 'temperature_2m_max': 29.15, 'temperature_2m_min': 25.3, 'temperature_2m_mean': 26.889585, 'precipitation_sum': 46.0, 'rain_sum': 46.0, 'wind_speed_10m_max': 29.598919, 'wind_gusts_10m_max': 44.28, 'wind_direction_10m_dominant': 277.8006, 'shortwave_radiation_sum': 12.73}
# {'date': DatetimeIndex(['1967-05-01 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1967-05-02', 'end_date': '1967-05-02', 'weather_code': 65.0, 'temperature_2m_max': 29.15, 'temperature_2m_min': 25.3, 'temperature_2m_mean': 26.889585, 'precipitation_sum': 46.0, 'rain_sum': 46.0, 'wind_speed_10m_max': 29.598919, 'wind_gusts_10m_max': 44.28, 'wind_direction_10m_dominant': 277.8006, 'shortwave_radiation_sum': 12.73}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1968-04-10 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1968-04-11', 'end_date': '1968-04-11', 'weather_code': 51.0, 'temperature_2m_max': 29.55, 'temperature_2m_min': 26.45, 'temperature_2m_mean': 27.72708, 'precipitation_sum': 1.0000001, 'rain_sum': 1.0000001, 'wind_speed_10m_max': 26.400545, 'wind_gusts_10m_max': 41.760002, 'wind_direction_10m_dominant': 261.9014, 'shortwave_radiation_sum': 20.29}
# {'date': DatetimeIndex(['1968-04-10 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1968-04-11', 'end_date': '1968-04-11', 'weather_code': 51.0, 'temperature_2m_max': 29.55, 'temperature_2m_min': 26.45, 'temperature_2m_mean': 27.72708, 'precipitation_sum': 1.0000001, 'rain_sum': 1.0000001, 'wind_speed_10m_max': 26.400545, 'wind_gusts_10m_max': 41.760002, 'wind_direction_10m_dominant': 261.9014, 'shortwave_radiation_sum': 20.29}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1969-04-13 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1969-04-14', 'end_date': '1969-04-14', 'weather_code': 63.0, 'temperature_2m_max': 31.45, 'temperature_2m_min': 26.7, 'temperature_2m_mean': 28.710417, 'precipitation_sum': 11.9, 'rain_sum': 11.9, 'wind_speed_10m_max': 37.483242, 'wind_gusts_10m_max': 56.16, 'wind_direction_10m_dominant': 264.24692, 'shortwave_radiation_sum': 21.7}
# {'date': DatetimeIndex(['1969-04-13 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1969-04-14', 'end_date': '1969-04-14', 'weather_code': 63.0, 'temperature_2m_max': 31.45, 'temperature_2m_min': 26.7, 'temperature_2m_mean': 28.710417, 'precipitation_sum': 11.9, 'rain_sum': 11.9, 'wind_speed_10m_max': 37.483242, 'wind_gusts_10m_max': 56.16, 'wind_direction_10m_dominant': 264.24692, 'shortwave_radiation_sum': 21.7}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1970-11-11 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1970-11-12', 'end_date': '1970-11-12', 'weather_code': 63.0, 'temperature_2m_max': 23.55, 'temperature_2m_min': 21.8, 'temperature_2m_mean': 22.727083, 'precipitation_sum': 47.499996, 'rain_sum': 47.499996, 'wind_speed_10m_max': 42.91405, 'wind_gusts_10m_max': 63.72, 'wind_direction_10m_dominant': 346.93845, 'shortwave_radiation_sum': 3.08}
# {'date': DatetimeIndex(['1970-11-11 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1970-11-12', 'end_date': '1970-11-12', 'weather_code': 63.0, 'temperature_2m_max': 23.55, 'temperature_2m_min': 21.8, 'temperature_2m_mean': 22.727083, 'precipitation_sum': 47.499996, 'rain_sum': 47.499996, 'wind_speed_10m_max': 42.91405, 'wind_gusts_10m_max': 63.72, 'wind_direction_10m_dominant': 346.93845, 'shortwave_radiation_sum': 3.08}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1970-04-12 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1970-04-13', 'end_date': '1970-04-13', 'weather_code': 2.0, 'temperature_2m_max': 32.6, 'temperature_2m_min': 24.55, 'temperature_2m_mean': 28.354164, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 17.654688, 'wind_gusts_10m_max': 28.08, 'wind_direction_10m_dominant': 166.5191, 'shortwave_radiation_sum': 25.35}
# {'date': DatetimeIndex(['1970-04-12 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1970-04-13', 'end_date': '1970-04-13', 'weather_code': 2.0, 'temperature_2m_max': 32.6, 'temperature_2m_min': 24.55, 'temperature_2m_mean': 28.354164, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 17.654688, 'wind_gusts_10m_max': 28.08, 'wind_direction_10m_dominant': 166.5191, 'shortwave_radiation_sum': 25.35}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1970-10-22 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1970-10-23', 'end_date': '1970-10-23', 'weather_code': 63.0, 'temperature_2m_max': 26.2, 'temperature_2m_min': 25.05, 'temperature_2m_mean': 25.589584, 'precipitation_sum': 30.599998, 'rain_sum': 30.599998, 'wind_speed_10m_max': 57.51556, 'wind_gusts_10m_max': 88.2, 'wind_direction_10m_dominant': 296.75772, 'shortwave_radiation_sum': 4.1}
# {'date': DatetimeIndex(['1970-10-22 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1970-10-23', 'end_date': '1970-10-23', 'weather_code': 63.0, 'temperature_2m_max': 26.2, 'temperature_2m_min': 25.05, 'temperature_2m_mean': 25.589584, 'precipitation_sum': 30.599998, 'rain_sum': 30.599998, 'wind_speed_10m_max': 57.51556, 'wind_gusts_10m_max': 88.2, 'wind_direction_10m_dominant': 296.75772, 'shortwave_radiation_sum': 4.1}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1971-05-07 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1971-05-08', 'end_date': '1971-05-08', 'weather_code': 63.0, 'temperature_2m_max': 27.5, 'temperature_2m_min': 24.55, 'temperature_2m_mean': 25.858332, 'precipitation_sum': 25.600002, 'rain_sum': 25.600002, 'wind_speed_10m_max': 44.751633, 'wind_gusts_10m_max': 70.2, 'wind_direction_10m_dominant': 254.45241, 'shortwave_radiation_sum': 20.91}
# {'date': DatetimeIndex(['1971-05-07 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1971-05-08', 'end_date': '1971-05-08', 'weather_code': 63.0, 'temperature_2m_max': 27.5, 'temperature_2m_min': 24.55, 'temperature_2m_mean': 25.858332, 'precipitation_sum': 25.600002, 'rain_sum': 25.600002, 'wind_speed_10m_max': 44.751633, 'wind_gusts_10m_max': 70.2, 'wind_direction_10m_dominant': 254.45241, 'shortwave_radiation_sum': 20.91}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1972-04-01 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1972-04-02', 'end_date': '1972-04-02', 'weather_code': 61.0, 'temperature_2m_max': 30.0, 'temperature_2m_min': 25.4, 'temperature_2m_mean': 27.393747, 'precipitation_sum': 4.9, 'rain_sum': 4.9, 'wind_speed_10m_max': 27.14123, 'wind_gusts_10m_max': 43.199997, 'wind_direction_10m_dominant': 266.2056, 'shortwave_radiation_sum': 21.09}
# {'date': DatetimeIndex(['1972-04-01 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1972-04-02', 'end_date': '1972-04-02', 'weather_code': 61.0, 'temperature_2m_max': 30.0, 'temperature_2m_min': 25.4, 'temperature_2m_mean': 27.393747, 'precipitation_sum': 4.9, 'rain_sum': 4.9, 'wind_speed_10m_max': 27.14123, 'wind_gusts_10m_max': 43.199997, 'wind_direction_10m_dominant': 266.2056, 'shortwave_radiation_sum': 21.09}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1972-06-24 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1972-06-25', 'end_date': '1972-06-25', 'weather_code': 63.0, 'temperature_2m_max': 27.6, 'temperature_2m_min': 25.05, 'temperature_2m_mean': 25.833334, 'precipitation_sum': 20.399996, 'rain_sum': 20.399996, 'wind_speed_10m_max': 25.14852, 'wind_gusts_10m_max': 36.36, 'wind_direction_10m_dominant': 282.5677, 'shortwave_radiation_sum': 8.83}
# {'date': DatetimeIndex(['1972-06-24 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1972-06-25', 'end_date': '1972-06-25', 'weather_code': 63.0, 'temperature_2m_max': 27.6, 'temperature_2m_min': 25.05, 'temperature_2m_mean': 25.833334, 'precipitation_sum': 20.399996, 'rain_sum': 20.399996, 'wind_speed_10m_max': 25.14852, 'wind_gusts_10m_max': 36.36, 'wind_direction_10m_dominant': 282.5677, 'shortwave_radiation_sum': 8.83}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1973-12-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1973-12-09', 'end_date': '1973-12-09', 'weather_code': 63.0, 'temperature_2m_max': 23.6, 'temperature_2m_min': 19.85, 'temperature_2m_mean': 21.262499, 'precipitation_sum': 34.499996, 'rain_sum': 34.499996, 'wind_speed_10m_max': 53.284863, 'wind_gusts_10m_max': 89.27999, 'wind_direction_10m_dominant': 315.17123, 'shortwave_radiation_sum': 1.89}
# {'date': DatetimeIndex(['1973-12-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1973-12-09', 'end_date': '1973-12-09', 'weather_code': 63.0, 'temperature_2m_max': 23.6, 'temperature_2m_min': 19.85, 'temperature_2m_mean': 21.262499, 'precipitation_sum': 34.499996, 'rain_sum': 34.499996, 'wind_speed_10m_max': 53.284863, 'wind_gusts_10m_max': 89.27999, 'wind_direction_10m_dominant': 315.17123, 'shortwave_radiation_sum': 1.89}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1973-04-11 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1973-04-12', 'end_date': '1973-04-12', 'weather_code': 53.0, 'temperature_2m_max': 30.85, 'temperature_2m_min': 26.65, 'temperature_2m_mean': 28.339584, 'precipitation_sum': 4.5999994, 'rain_sum': 4.5999994, 'wind_speed_10m_max': 33.818928, 'wind_gusts_10m_max': 55.44, 'wind_direction_10m_dominant': 264.9859, 'shortwave_radiation_sum': 21.92}
# {'date': DatetimeIndex(['1973-04-11 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1973-04-12', 'end_date': '1973-04-12', 'weather_code': 53.0, 'temperature_2m_max': 30.85, 'temperature_2m_min': 26.65, 'temperature_2m_mean': 28.339584, 'precipitation_sum': 4.5999994, 'rain_sum': 4.5999994, 'wind_speed_10m_max': 33.818928, 'wind_gusts_10m_max': 55.44, 'wind_direction_10m_dominant': 264.9859, 'shortwave_radiation_sum': 21.92}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1974-11-27 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1974-11-28', 'end_date': '1974-11-28', 'weather_code': 65.0, 'temperature_2m_max': 23.35, 'temperature_2m_min': 21.75, 'temperature_2m_mean': 22.722918, 'precipitation_sum': 88.799995, 'rain_sum': 88.799995, 'wind_speed_10m_max': 40.83898, 'wind_gusts_10m_max': 87.479996, 'wind_direction_10m_dominant': 47.69192, 'shortwave_radiation_sum': 3.67}
# {'date': DatetimeIndex(['1974-11-27 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1974-11-28', 'end_date': '1974-11-28', 'weather_code': 65.0, 'temperature_2m_max': 23.35, 'temperature_2m_min': 21.75, 'temperature_2m_mean': 22.722918, 'precipitation_sum': 88.799995, 'rain_sum': 88.799995, 'wind_speed_10m_max': 40.83898, 'wind_gusts_10m_max': 87.479996, 'wind_direction_10m_dominant': 47.69192, 'shortwave_radiation_sum': 3.67}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1976-04-09 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1976-04-10', 'end_date': '1976-04-10', 'weather_code': 63.0, 'temperature_2m_max': 27.7, 'temperature_2m_min': 25.55, 'temperature_2m_mean': 26.764587, 'precipitation_sum': 18.100002, 'rain_sum': 18.100002, 'wind_speed_10m_max': 30.421598, 'wind_gusts_10m_max': 45.719997, 'wind_direction_10m_dominant': 260.21304, 'shortwave_radiation_sum': 17.54}
# {'date': DatetimeIndex(['1976-04-09 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1976-04-10', 'end_date': '1976-04-10', 'weather_code': 63.0, 'temperature_2m_max': 27.7, 'temperature_2m_min': 25.55, 'temperature_2m_mean': 26.764587, 'precipitation_sum': 18.100002, 'rain_sum': 18.100002, 'wind_speed_10m_max': 30.421598, 'wind_gusts_10m_max': 45.719997, 'wind_direction_10m_dominant': 260.21304, 'shortwave_radiation_sum': 17.54}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1976-05-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1976-05-09', 'end_date': '1976-05-09', 'weather_code': 63.0, 'temperature_2m_max': 28.35, 'temperature_2m_min': 24.15, 'temperature_2m_mean': 25.766668, 'precipitation_sum': 38.100002, 'rain_sum': 38.100002, 'wind_speed_10m_max': 25.929996, 'wind_gusts_10m_max': 39.96, 'wind_direction_10m_dominant': 265.82074, 'shortwave_radiation_sum': 14.14}
# {'date': DatetimeIndex(['1976-05-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1976-05-09', 'end_date': '1976-05-09', 'weather_code': 63.0, 'temperature_2m_max': 28.35, 'temperature_2m_min': 24.15, 'temperature_2m_mean': 25.766668, 'precipitation_sum': 38.100002, 'rain_sum': 38.100002, 'wind_speed_10m_max': 25.929996, 'wind_gusts_10m_max': 39.96, 'wind_direction_10m_dominant': 265.82074, 'shortwave_radiation_sum': 14.14}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1976-06-14 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1976-06-15', 'end_date': '1976-06-15', 'weather_code': 63.0, 'temperature_2m_max': 29.75, 'temperature_2m_min': 25.35, 'temperature_2m_mean': 27.058329, 'precipitation_sum': 19.8, 'rain_sum': 19.8, 'wind_speed_10m_max': 27.219902, 'wind_gusts_10m_max': 40.32, 'wind_direction_10m_dominant': 283.7961, 'shortwave_radiation_sum': 18.3}
# {'date': DatetimeIndex(['1976-06-14 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1976-06-15', 'end_date': '1976-06-15', 'weather_code': 63.0, 'temperature_2m_max': 29.75, 'temperature_2m_min': 25.35, 'temperature_2m_mean': 27.058329, 'precipitation_sum': 19.8, 'rain_sum': 19.8, 'wind_speed_10m_max': 27.219902, 'wind_gusts_10m_max': 40.32, 'wind_direction_10m_dominant': 283.7961, 'shortwave_radiation_sum': 18.3}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1977-10-05 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1977-10-06', 'end_date': '1977-10-06', 'weather_code': 51.0, 'temperature_2m_max': 28.95, 'temperature_2m_min': 25.5, 'temperature_2m_mean': 26.90417, 'precipitation_sum': 2.0, 'rain_sum': 2.0, 'wind_speed_10m_max': 12.594856, 'wind_gusts_10m_max': 23.039999, 'wind_direction_10m_dominant': 259.63968, 'shortwave_radiation_sum': 17.58}
# {'date': DatetimeIndex(['1977-10-05 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1977-10-06', 'end_date': '1977-10-06', 'weather_code': 51.0, 'temperature_2m_max': 28.95, 'temperature_2m_min': 25.5, 'temperature_2m_mean': 26.90417, 'precipitation_sum': 2.0, 'rain_sum': 2.0, 'wind_speed_10m_max': 12.594856, 'wind_gusts_10m_max': 23.039999, 'wind_direction_10m_dominant': 259.63968, 'shortwave_radiation_sum': 17.58}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1977-04-23 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1977-04-24', 'end_date': '1977-04-24', 'weather_code': 51.0, 'temperature_2m_max': 30.6, 'temperature_2m_min': 25.35, 'temperature_2m_mean': 27.86875, 'precipitation_sum': 0.2, 'rain_sum': 0.2, 'wind_speed_10m_max': 17.148247, 'wind_gusts_10m_max': 26.28, 'wind_direction_10m_dominant': 244.96434, 'shortwave_radiation_sum': 23.86}
# {'date': DatetimeIndex(['1977-04-23 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1977-04-24', 'end_date': '1977-04-24', 'weather_code': 51.0, 'temperature_2m_max': 30.6, 'temperature_2m_min': 25.35, 'temperature_2m_mean': 27.86875, 'precipitation_sum': 0.2, 'rain_sum': 0.2, 'wind_speed_10m_max': 17.148247, 'wind_gusts_10m_max': 26.28, 'wind_direction_10m_dominant': 244.96434, 'shortwave_radiation_sum': 23.86}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1977-03-31 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1977-04-01', 'end_date': '1977-04-01', 'weather_code': 51.0, 'temperature_2m_max': 30.6, 'temperature_2m_min': 26.25, 'temperature_2m_mean': 28.145834, 'precipitation_sum': 0.6, 'rain_sum': 0.6, 'wind_speed_10m_max': 34.763775, 'wind_gusts_10m_max': 53.28, 'wind_direction_10m_dominant': 267.6727, 'shortwave_radiation_sum': 20.4}
# {'date': DatetimeIndex(['1977-03-31 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1977-04-01', 'end_date': '1977-04-01', 'weather_code': 51.0, 'temperature_2m_max': 30.6, 'temperature_2m_min': 26.25, 'temperature_2m_mean': 28.145834, 'precipitation_sum': 0.6, 'rain_sum': 0.6, 'wind_speed_10m_max': 34.763775, 'wind_gusts_10m_max': 53.28, 'wind_direction_10m_dominant': 267.6727, 'shortwave_radiation_sum': 20.4}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1977-10-12 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1977-10-13', 'end_date': '1977-10-13', 'weather_code': 61.0, 'temperature_2m_max': 28.5, 'temperature_2m_min': 24.15, 'temperature_2m_mean': 25.960419, 'precipitation_sum': 6.1, 'rain_sum': 6.1, 'wind_speed_10m_max': 7.491114, 'wind_gusts_10m_max': 16.919998, 'wind_direction_10m_dominant': 143.42694, 'shortwave_radiation_sum': 16.91}
# {'date': DatetimeIndex(['1977-10-12 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1977-10-13', 'end_date': '1977-10-13', 'weather_code': 61.0, 'temperature_2m_max': 28.5, 'temperature_2m_min': 24.15, 'temperature_2m_mean': 25.960419, 'precipitation_sum': 6.1, 'rain_sum': 6.1, 'wind_speed_10m_max': 7.491114, 'wind_gusts_10m_max': 16.919998, 'wind_direction_10m_dominant': 143.42694, 'shortwave_radiation_sum': 16.91}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1978-04-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1978-04-09', 'end_date': '1978-04-09', 'weather_code': 0.0, 'temperature_2m_max': 32.9, 'temperature_2m_min': 22.8, 'temperature_2m_mean': 27.927084, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 18.359999, 'wind_gusts_10m_max': 27.0, 'wind_direction_10m_dominant': 159.93022, 'shortwave_radiation_sum': 26.4}
# {'date': DatetimeIndex(['1978-04-08 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1978-04-09', 'end_date': '1978-04-09', 'weather_code': 0.0, 'temperature_2m_max': 32.9, 'temperature_2m_min': 22.8, 'temperature_2m_mean': 27.927084, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 18.359999, 'wind_gusts_10m_max': 27.0, 'wind_direction_10m_dominant': 159.93022, 'shortwave_radiation_sum': 26.4}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1978-05-04 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1978-05-05', 'end_date': '1978-05-05', 'weather_code': 2.0, 'temperature_2m_max': 30.9, 'temperature_2m_min': 25.35, 'temperature_2m_mean': 28.510414, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 15.379206, 'wind_gusts_10m_max': 27.0, 'wind_direction_10m_dominant': 222.52428, 'shortwave_radiation_sum': 20.8}
# {'date': DatetimeIndex(['1978-05-04 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1978-05-05', 'end_date': '1978-05-05', 'weather_code': 2.0, 'temperature_2m_max': 30.9, 'temperature_2m_min': 25.35, 'temperature_2m_mean': 28.510414, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 15.379206, 'wind_gusts_10m_max': 27.0, 'wind_direction_10m_dominant': 222.52428, 'shortwave_radiation_sum': 20.8}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1979-05-01 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1979-05-02', 'end_date': '1979-05-02', 'weather_code': 63.0, 'temperature_2m_max': 29.1, 'temperature_2m_min': 24.75, 'temperature_2m_mean': 26.866667, 'precipitation_sum': 34.1, 'rain_sum': 34.1, 'wind_speed_10m_max': 28.696312, 'wind_gusts_10m_max': 47.88, 'wind_direction_10m_dominant': 178.0489, 'shortwave_radiation_sum': 13.72}
# {'date': DatetimeIndex(['1979-05-01 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1979-05-02', 'end_date': '1979-05-02', 'weather_code': 63.0, 'temperature_2m_max': 29.1, 'temperature_2m_min': 24.75, 'temperature_2m_mean': 26.866667, 'precipitation_sum': 34.1, 'rain_sum': 34.1, 'wind_speed_10m_max': 28.696312, 'wind_gusts_10m_max': 47.88, 'wind_direction_10m_dominant': 178.0489, 'shortwave_radiation_sum': 13.72}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1979-08-16 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1979-08-17', 'end_date': '1979-08-17', 'weather_code': 53.0, 'temperature_2m_max': 28.75, 'temperature_2m_min': 25.4, 'temperature_2m_mean': 26.847914, 'precipitation_sum': 6.5000005, 'rain_sum': 6.5000005, 'wind_speed_10m_max': 23.023119, 'wind_gusts_10m_max': 37.079998, 'wind_direction_10m_dominant': 175.68666, 'shortwave_radiation_sum': 18.09}
# {'date': DatetimeIndex(['1979-08-16 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1979-08-17', 'end_date': '1979-08-17', 'weather_code': 53.0, 'temperature_2m_max': 28.75, 'temperature_2m_min': 25.4, 'temperature_2m_mean': 26.847914, 'precipitation_sum': 6.5000005, 'rain_sum': 6.5000005, 'wind_speed_10m_max': 23.023119, 'wind_gusts_10m_max': 37.079998, 'wind_direction_10m_dominant': 175.68666, 'shortwave_radiation_sum': 18.09}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1981-04-14 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1981-04-15', 'end_date': '1981-04-15', 'weather_code': 61.0, 'temperature_2m_max': 27.9, 'temperature_2m_min': 23.45, 'temperature_2m_mean': 25.093752, 'precipitation_sum': 9.5, 'rain_sum': 9.5, 'wind_speed_10m_max': 19.011953, 'wind_gusts_10m_max': 33.839996, 'wind_direction_10m_dominant': 168.85223, 'shortwave_radiation_sum': 18.43}
# {'date': DatetimeIndex(['1981-04-14 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1981-04-15', 'end_date': '1981-04-15', 'weather_code': 61.0, 'temperature_2m_max': 27.9, 'temperature_2m_min': 23.45, 'temperature_2m_mean': 25.093752, 'precipitation_sum': 9.5, 'rain_sum': 9.5, 'wind_speed_10m_max': 19.011953, 'wind_gusts_10m_max': 33.839996, 'wind_direction_10m_dominant': 168.85223, 'shortwave_radiation_sum': 18.43}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1981-12-10 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1981-12-11', 'end_date': '1981-12-11', 'weather_code': 63.0, 'temperature_2m_max': 24.55, 'temperature_2m_min': 21.8, 'temperature_2m_mean': 23.231249, 'precipitation_sum': 14.1, 'rain_sum': 14.1, 'wind_speed_10m_max': 36.17955, 'wind_gusts_10m_max': 61.56, 'wind_direction_10m_dominant': 189.77357, 'shortwave_radiation_sum': 9.21}
# {'date': DatetimeIndex(['1981-12-10 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1981-12-11', 'end_date': '1981-12-11', 'weather_code': 63.0, 'temperature_2m_max': 24.55, 'temperature_2m_min': 21.8, 'temperature_2m_mean': 23.231249, 'precipitation_sum': 14.1, 'rain_sum': 14.1, 'wind_speed_10m_max': 36.17955, 'wind_gusts_10m_max': 61.56, 'wind_direction_10m_dominant': 189.77357, 'shortwave_radiation_sum': 9.21}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1981-03-05 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1981-03-06', 'end_date': '1981-03-06', 'weather_code': 0.0, 'temperature_2m_max': 30.0, 'temperature_2m_min': 19.5, 'temperature_2m_mean': 24.922918, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 15.646544, 'wind_gusts_10m_max': 25.199999, 'wind_direction_10m_dominant': 297.96603, 'shortwave_radiation_sum': 23.51}
# {'date': DatetimeIndex(['1981-03-05 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1981-03-06', 'end_date': '1981-03-06', 'weather_code': 0.0, 'temperature_2m_max': 30.0, 'temperature_2m_min': 19.5, 'temperature_2m_mean': 24.922918, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 15.646544, 'wind_gusts_10m_max': 25.199999, 'wind_direction_10m_dominant': 297.96603, 'shortwave_radiation_sum': 23.51}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1982-09-06 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1982-09-07', 'end_date': '1982-09-07', 'weather_code': 53.0, 'temperature_2m_max': 30.45, 'temperature_2m_min': 25.8, 'temperature_2m_mean': 27.820831, 'precipitation_sum': 2.5, 'rain_sum': 2.5, 'wind_speed_10m_max': 12.620554, 'wind_gusts_10m_max': 22.319998, 'wind_direction_10m_dominant': 154.79085, 'shortwave_radiation_sum': 19.89}
# {'date': DatetimeIndex(['1982-09-06 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1982-09-07', 'end_date': '1982-09-07', 'weather_code': 53.0, 'temperature_2m_max': 30.45, 'temperature_2m_min': 25.8, 'temperature_2m_mean': 27.820831, 'precipitation_sum': 2.5, 'rain_sum': 2.5, 'wind_speed_10m_max': 12.620554, 'wind_gusts_10m_max': 22.319998, 'wind_direction_10m_dominant': 154.79085, 'shortwave_radiation_sum': 19.89}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1983-04-25 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1983-04-26', 'end_date': '1983-04-26', 'weather_code': 51.0, 'temperature_2m_max': 29.6, 'temperature_2m_min': 24.7, 'temperature_2m_mean': 27.237497, 'precipitation_sum': 0.90000004, 'rain_sum': 0.90000004, 'wind_speed_10m_max': 23.828083, 'wind_gusts_10m_max': 39.96, 'wind_direction_10m_dominant': 181.63321, 'shortwave_radiation_sum': 23.22}
# {'date': DatetimeIndex(['1983-04-25 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1983-04-26', 'end_date': '1983-04-26', 'weather_code': 51.0, 'temperature_2m_max': 29.6, 'temperature_2m_min': 24.7, 'temperature_2m_mean': 27.237497, 'precipitation_sum': 0.90000004, 'rain_sum': 0.90000004, 'wind_speed_10m_max': 23.828083, 'wind_gusts_10m_max': 39.96, 'wind_direction_10m_dominant': 181.63321, 'shortwave_radiation_sum': 23.22}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1983-03-20 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1983-03-21', 'end_date': '1983-03-21', 'weather_code': 61.0, 'temperature_2m_max': 27.6, 'temperature_2m_min': 23.2, 'temperature_2m_mean': 25.606247, 'precipitation_sum': 6.5, 'rain_sum': 6.5, 'wind_speed_10m_max': 32.688713, 'wind_gusts_10m_max': 49.32, 'wind_direction_10m_dominant': 185.2692, 'shortwave_radiation_sum': 18.71}
# {'date': DatetimeIndex(['1983-03-20 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1983-03-21', 'end_date': '1983-03-21', 'weather_code': 61.0, 'temperature_2m_max': 27.6, 'temperature_2m_min': 23.2, 'temperature_2m_mean': 25.606247, 'precipitation_sum': 6.5, 'rain_sum': 6.5, 'wind_speed_10m_max': 32.688713, 'wind_gusts_10m_max': 49.32, 'wind_direction_10m_dominant': 185.2692, 'shortwave_radiation_sum': 18.71}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1983-10-14 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1983-10-15', 'end_date': '1983-10-15', 'weather_code': 65.0, 'temperature_2m_max': 26.25, 'temperature_2m_min': 24.55, 'temperature_2m_mean': 25.483332, 'precipitation_sum': 122.50001, 'rain_sum': 122.50001, 'wind_speed_10m_max': 17.811815, 'wind_gusts_10m_max': 35.64, 'wind_direction_10m_dominant': 216.24461, 'shortwave_radiation_sum': 6.02}
# {'date': DatetimeIndex(['1983-10-14 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1983-10-15', 'end_date': '1983-10-15', 'weather_code': 65.0, 'temperature_2m_max': 26.25, 'temperature_2m_min': 24.55, 'temperature_2m_mean': 25.483332, 'precipitation_sum': 122.50001, 'rain_sum': 122.50001, 'wind_speed_10m_max': 17.811815, 'wind_gusts_10m_max': 35.64, 'wind_direction_10m_dominant': 216.24461, 'shortwave_radiation_sum': 6.02}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1983-11-12 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1983-11-13', 'end_date': '1983-11-13', 'weather_code': 1.0, 'temperature_2m_max': 27.35, 'temperature_2m_min': 21.75, 'temperature_2m_mean': 24.27292, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 13.684735, 'wind_gusts_10m_max': 21.599998, 'wind_direction_10m_dominant': 342.96884, 'shortwave_radiation_sum': 17.45}
# {'date': DatetimeIndex(['1983-11-12 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1983-11-13', 'end_date': '1983-11-13', 'weather_code': 1.0, 'temperature_2m_max': 27.35, 'temperature_2m_min': 21.75, 'temperature_2m_mean': 24.27292, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 13.684735, 'wind_gusts_10m_max': 21.599998, 'wind_direction_10m_dominant': 342.96884, 'shortwave_radiation_sum': 17.45}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1985-05-23 18:00:00+00:00', '1985-05-24 18:00:00+00:00',
#                '1985-05-25 18:00:00+00:00', '1985-05-26 18:00:00+00:00',
#                '1985-05-27 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1985-05-24', 'end_date': '1985-05-28', 'weather_code': 58.2, 'temperature_2m_max': 29.25, 'temperature_2m_min': 25.95, 'temperature_2m_mean': 27.373333, 'precipitation_sum': 27.86, 'rain_sum': 27.86, 'wind_speed_10m_max': 32.67483, 'wind_gusts_10m_max': 52.415997, 'wind_direction_10m_dominant': 154.92874, 'shortwave_radiation_sum': 13.8480015}
# {'date': DatetimeIndex(['1985-05-23 18:00:00+00:00', '1985-05-24 18:00:00+00:00',
#                '1985-05-25 18:00:00+00:00', '1985-05-26 18:00:00+00:00',
#                '1985-05-27 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1985-05-24', 'end_date': '1985-05-28', 'weather_code': 58.2, 'temperature_2m_max': 29.25, 'temperature_2m_min': 25.95, 'temperature_2m_mean': 27.373333, 'precipitation_sum': 27.86, 'rain_sum': 27.86, 'wind_speed_10m_max': 32.67483, 'wind_gusts_10m_max': 52.415997, 'wind_direction_10m_dominant': 154.92874, 'shortwave_radiation_sum': 13.8480015}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1985-03-27 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1985-03-28', 'end_date': '1985-03-28', 'weather_code': 51.0, 'temperature_2m_max': 28.95, 'temperature_2m_min': 24.2, 'temperature_2m_mean': 26.302084, 'precipitation_sum': 0.8, 'rain_sum': 0.8, 'wind_speed_10m_max': 24.464113, 'wind_gusts_10m_max': 37.079998, 'wind_direction_10m_dominant': 196.41048, 'shortwave_radiation_sum': 22.05}
# {'date': DatetimeIndex(['1985-03-27 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1985-03-28', 'end_date': '1985-03-28', 'weather_code': 51.0, 'temperature_2m_max': 28.95, 'temperature_2m_min': 24.2, 'temperature_2m_mean': 26.302084, 'precipitation_sum': 0.8, 'rain_sum': 0.8, 'wind_speed_10m_max': 24.464113, 'wind_gusts_10m_max': 37.079998, 'wind_direction_10m_dominant': 196.41048, 'shortwave_radiation_sum': 22.05}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# {'date': DatetimeIndex(['1985-10-15 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1985-10-16', 'end_date': '1985-10-16', 'weather_code': 61.0, 'temperature_2m_max': 29.5, 'temperature_2m_min': 26.05, 'temperature_2m_mean': 26.856253, 'precipitation_sum': 4.2, 'rain_sum': 4.2, 'wind_speed_10m_max': 32.559605, 'wind_gusts_10m_max': 50.76, 'wind_direction_10m_dominant': 147.53836, 'shortwave_radiation_sum': 14.83}
# {'date': DatetimeIndex(['1985-10-15 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '1985-10-16', 'end_date': '1985-10-16', 'weather_code': 61.0, 'temperature_2m_max': 29.5, 'temperature_2m_min': 26.05, 'temperature_2m_mean': 26.856253, 'precipitation_sum': 4.2, 'rain_sum': 4.2, 'wind_speed_10m_max': 32.559605, 'wind_gusts_10m_max': 50.76, 'wind_direction_10m_dominant': 147.53836, 'shortwave_radiation_sum': 14.83}
# Coordinates 22.31985855102539°N 91.8614273071289°E
# Elevation 3.0 m asl
# Timezone b'Asia/Dhaka' b'+06'
# Timezone difference to GMT+0 21600 s
# ...
#                '2016-05-14 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2016-05-13', 'end_date': '2016-05-15', 'weather_code': 34.333332, 'temperature_2m_max': 31.416666, 'temperature_2m_min': 27.9, 'temperature_2m_mean': 29.402777, 'precipitation_sum': 0.5, 'rain_sum': 0.5, 'wind_speed_10m_max': 21.10687, 'wind_gusts_10m_max': 33.84, 'wind_direction_10m_dominant': 200.028, 'shortwave_radiation_sum': 21.720001}, {'date': DatetimeIndex(['2016-07-18 18:00:00+00:00', '2016-07-19 18:00:00+00:00',
#                '2016-07-20 18:00:00+00:00', '2016-07-21 18:00:00+00:00',
#                '2016-07-22 18:00:00+00:00', '2016-07-23 18:00:00+00:00',
#                '2016-07-24 18:00:00+00:00', '2016-07-25 18:00:00+00:00',
#                '2016-07-26 18:00:00+00:00', '2016-07-27 18:00:00+00:00',
#                '2016-07-28 18:00:00+00:00', '2016-07-29 18:00:00+00:00',
#                '2016-07-30 18:00:00+00:00', '2016-07-31 18:00:00+00:00',
#                '2016-08-01 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2016-07-19', 'end_date': '2016-08-02', 'weather_code': 58.066666, 'temperature_2m_max': 29.273335, 'temperature_2m_min': 25.606668, 'temperature_2m_mean': 27.145973, 'precipitation_sum': 9.240001, 'rain_sum': 9.240001, 'wind_speed_10m_max': 21.223894, 'wind_gusts_10m_max': 32.16, 'wind_direction_10m_dominant': 179.37279, 'shortwave_radiation_sum': 15.491334}, {'date': DatetimeIndex(['2017-06-11 18:00:00+00:00', '2017-06-12 18:00:00+00:00',
#                '2017-06-13 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2017-06-12', 'end_date': '2017-06-14', 'weather_code': 63.666668, 'temperature_2m_max': 28.433334, 'temperature_2m_min': 25.283335, 'temperature_2m_mean': 26.516668, 'precipitation_sum': 86.533325, 'rain_sum': 86.533325, 'wind_speed_10m_max': 33.50684, 'wind_gusts_10m_max': 66.72, 'wind_direction_10m_dominant': 184.172, 'shortwave_radiation_sum': 6.626667}, {'date': DatetimeIndex(['2017-04-30 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2017-05-01', 'end_date': '2017-05-01', 'weather_code': 1.0, 'temperature_2m_max': 32.15, 'temperature_2m_min': 23.8, 'temperature_2m_mean': 27.322916, 'precipitation_sum': 0.0, 'rain_sum': 0.0, 'wind_speed_10m_max': 18.532133, 'wind_gusts_10m_max': 38.88, 'wind_direction_10m_dominant': 193.65242, 'shortwave_radiation_sum': 27.13}, {'date': DatetimeIndex(['2017-03-27 18:00:00+00:00', '2017-03-28 18:00:00+00:00',
#                '2017-03-29 18:00:00+00:00', '2017-03-30 18:00:00+00:00',
#                '2017-03-31 18:00:00+00:00', '2017-04-01 18:00:00+00:00',
#                '2017-04-02 18:00:00+00:00', '2017-04-03 18:00:00+00:00',
#                '2017-04-04 18:00:00+00:00', '2017-04-05 18:00:00+00:00',
#                '2017-04-06 18:00:00+00:00', '2017-04-07 18:00:00+00:00',
#                '2017-04-08 18:00:00+00:00', '2017-04-09 18:00:00+00:00',
#                '2017-04-10 18:00:00+00:00', '2017-04-11 18:00:00+00:00',
#                '2017-04-12 18:00:00+00:00', '2017-04-13 18:00:00+00:00',
#                '2017-04-14 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2017-03-28', 'end_date': '2017-04-15', 'weather_code': 42.894737, 'temperature_2m_max': 30.481583, 'temperature_2m_min': 23.760525, 'temperature_2m_mean': 26.90011, 'precipitation_sum': 2.1736841, 'rain_sum': 2.1736841, 'wind_speed_10m_max': 21.503931, 'wind_gusts_10m_max': 43.99579, 'wind_direction_10m_dominant': 204.73277, 'shortwave_radiation_sum': 21.961054}, {'date': DatetimeIndex(['2017-05-29 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2017-05-30', 'end_date': '2017-05-30', 'weather_code': 65.0, 'temperature_2m_max': 27.1, 'temperature_2m_min': 24.7, 'temperature_2m_mean': 25.9625, 'precipitation_sum': 106.799995, 'rain_sum': 106.799995, 'wind_speed_10m_max': 49.16208, 'wind_gusts_10m_max': 91.799995, 'wind_direction_10m_dominant': 300.72946, 'shortwave_radiation_sum': 2.76}, {'date': DatetimeIndex(['2017-11-02 18:00:00+00:00', '2017-11-03 18:00:00+00:00',
#                '2017-11-04 18:00:00+00:00', '2017-11-05 18:00:00+00:00',
#                '2017-11-06 18:00:00+00:00', '2017-11-07 18:00:00+00:00',
#                '2017-11-08 18:00:00+00:00', '2017-11-09 18:00:00+00:00',
#                '2017-11-10 18:00:00+00:00', '2017-11-11 18:00:00+00:00',
#                '2017-11-12 18:00:00+00:00', '2017-11-13 18:00:00+00:00',
#                '2017-11-14 18:00:00+00:00', '2017-11-15 18:00:00+00:00',
#                '2017-11-16 18:00:00+00:00', '2017-11-17 18:00:00+00:00',
#                '2017-11-18 18:00:00+00:00', '2017-11-19 18:00:00+00:00',
#                '2017-11-20 18:00:00+00:00', '2017-11-21 18:00:00+00:00',
#                '2017-11-22 18:00:00+00:00', '2017-11-23 18:00:00+00:00',
#                '2017-11-24 18:00:00+00:00', '2017-11-25 18:00:00+00:00',
#                '2017-11-26 18:00:00+00:00', '2017-11-27 18:00:00+00:00',
#                '2017-11-28 18:00:00+00:00', '2017-11-29 18:00:00+00:00',
#                '2017-11-30 18:00:00+00:00', '2017-12-01 18:00:00+00:00',
#                '2017-12-02 18:00:00+00:00', '2017-12-03 18:00:00+00:00',
#                '2017-12-04 18:00:00+00:00', '2017-12-05 18:00:00+00:00',
#                '2017-12-06 18:00:00+00:00', '2017-12-07 18:00:00+00:00',
#                '2017-12-08 18:00:00+00:00', '2017-12-09 18:00:00+00:00',
#                '2017-12-10 18:00:00+00:00', '2017-12-11 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2017-11-03', 'end_date': '2017-12-12', 'weather_code': 19.175, 'temperature_2m_max': 27.9375, 'temperature_2m_min': 19.24375, 'temperature_2m_mean': 22.998646, 'precipitation_sum': 1.3625, 'rain_sum': 1.3625, 'wind_speed_10m_max': 10.90711, 'wind_gusts_10m_max': 22.059, 'wind_direction_10m_dominant': 223.78525, 'shortwave_radiation_sum': 14.82475}, {'date': DatetimeIndex(['2017-08-09 18:00:00+00:00', '2017-08-10 18:00:00+00:00',
#                '2017-08-11 18:00:00+00:00', '2017-08-12 18:00:00+00:00',
#                '2017-08-13 18:00:00+00:00', '2017-08-14 18:00:00+00:00',
#                '2017-08-15 18:00:00+00:00', '2017-08-16 18:00:00+00:00',
#                '2017-08-17 18:00:00+00:00', '2017-08-18 18:00:00+00:00',
#                '2017-08-19 18:00:00+00:00', '2017-08-20 18:00:00+00:00',
#                '2017-08-21 18:00:00+00:00', '2017-08-22 18:00:00+00:00',
#                '2017-08-23 18:00:00+00:00', '2017-08-24 18:00:00+00:00',
#                '2017-08-25 18:00:00+00:00', '2017-08-26 18:00:00+00:00',
#                '2017-08-27 18:00:00+00:00', '2017-08-28 18:00:00+00:00',
#                '2017-08-29 18:00:00+00:00', '2017-08-30 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2017-08-10', 'end_date': '2017-08-31', 'weather_code': 60.272728, 'temperature_2m_max': 29.400002, 'temperature_2m_min': 24.849998, 'temperature_2m_mean': 26.808998, 'precipitation_sum': 14.018183, 'rain_sum': 14.018183, 'wind_speed_10m_max': 17.181047, 'wind_gusts_10m_max': 35.214542, 'wind_direction_10m_dominant': 163.45486, 'shortwave_radiation_sum': 13.44591}, {'date': DatetimeIndex(['2018-06-04 18:00:00+00:00', '2018-06-05 18:00:00+00:00',
#                '2018-06-06 18:00:00+00:00', '2018-06-07 18:00:00+00:00',
#                '2018-06-08 18:00:00+00:00', '2018-06-09 18:00:00+00:00',
#                '2018-06-10 18:00:00+00:00', '2018-06-11 18:00:00+00:00',
#                '2018-06-12 18:00:00+00:00', '2018-06-13 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2018-06-05', 'end_date': '2018-06-14', 'weather_code': 63.8, 'temperature_2m_max': 29.61, 'temperature_2m_min': 25.495, 'temperature_2m_mean': 27.431873, 'precipitation_sum': 58.18, 'rain_sum': 58.18, 'wind_speed_10m_max': 19.93331, 'wind_gusts_10m_max': 39.78, 'wind_direction_10m_dominant': 152.3208, 'shortwave_radiation_sum': 11.289999}, {'date': DatetimeIndex(['2018-04-28 18:00:00+00:00', '2018-04-29 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2018-04-29', 'end_date': '2018-04-30', 'weather_code': 54.0, 'temperature_2m_max': 31.95, 'temperature_2m_min': 24.474998, 'temperature_2m_mean': 27.073961, 'precipitation_sum': 2.5, 'rain_sum': 2.5, 'wind_speed_10m_max': 19.911598, 'wind_gusts_10m_max': 41.58, 'wind_direction_10m_dominant': 177.94699, 'shortwave_radiation_sum': 17.150002}, {'date': DatetimeIndex(['2017-12-31 18:00:00+00:00', '2018-01-01 18:00:00+00:00',
#                '2018-01-02 18:00:00+00:00', '2018-01-03 18:00:00+00:00',
#                '2018-01-04 18:00:00+00:00', '2018-01-05 18:00:00+00:00',
#                '2018-01-06 18:00:00+00:00', '2018-01-07 18:00:00+00:00',
#                '2018-01-08 18:00:00+00:00', '2018-01-09 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2018-01-01', 'end_date': '2018-01-10', 'weather_code': 16.9, 'temperature_2m_max': 22.71, 'temperature_2m_min': 13.875, 'temperature_2m_mean': 17.7675, 'precipitation_sum': 1.2299999, 'rain_sum': 1.2299999, 'wind_speed_10m_max': 11.23049, 'wind_gusts_10m_max': 24.336, 'wind_direction_10m_dominant': 303.38855, 'shortwave_radiation_sum': 13.723}, {'date': DatetimeIndex(['2018-05-19 18:00:00+00:00', '2018-05-20 18:00:00+00:00',
#                '2018-05-21 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2018-05-20', 'end_date': '2018-05-22', 'weather_code': 59.0, 'temperature_2m_max': 29.683334, 'temperature_2m_min': 23.916666, 'temperature_2m_mean': 26.639582, 'precipitation_sum': 8.8, 'rain_sum': 8.8, 'wind_speed_10m_max': 16.221952, 'wind_gusts_10m_max': 37.679996, 'wind_direction_10m_dominant': 166.8745, 'shortwave_radiation_sum': 15.71}, {'date': DatetimeIndex(['2019-03-30 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2019-03-31', 'end_date': '2019-03-31', 'weather_code': 61.0, 'temperature_2m_max': 30.65, 'temperature_2m_min': 23.95, 'temperature_2m_mean': 26.847916, 'precipitation_sum': 2.8, 'rain_sum': 2.8, 'wind_speed_10m_max': 20.188908, 'wind_gusts_10m_max': 41.039997, 'wind_direction_10m_dominant': 178.6155, 'shortwave_radiation_sum': 17.74}, {'date': DatetimeIndex(['2019-07-01 18:00:00+00:00', '2019-07-02 18:00:00+00:00',
#                '2019-07-03 18:00:00+00:00', '2019-07-04 18:00:00+00:00',
#                '2019-07-05 18:00:00+00:00', '2019-07-06 18:00:00+00:00',
#                '2019-07-07 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2019-07-02', 'end_date': '2019-07-08', 'weather_code': 61.857143, 'temperature_2m_max': 28.821428, 'temperature_2m_min': 25.492857, 'temperature_2m_mean': 26.879763, 'precipitation_sum': 40.8, 'rain_sum': 40.8, 'wind_speed_10m_max': 27.310246, 'wind_gusts_10m_max': 52.354282, 'wind_direction_10m_dominant': 168.236, 'shortwave_radiation_sum': 11.83}, {'date': DatetimeIndex(['2019-05-03 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2019-05-04', 'end_date': '2019-05-04', 'weather_code': 63.0, 'temperature_2m_max': 30.95, 'temperature_2m_min': 25.95, 'temperature_2m_mean': 27.895838, 'precipitation_sum': 21.900002, 'rain_sum': 21.900002, 'wind_speed_10m_max': 32.209442, 'wind_gusts_10m_max': 79.2, 'wind_direction_10m_dominant': 185.17484, 'shortwave_radiation_sum': 13.19}, {'date': DatetimeIndex(['2019-11-08 18:00:00+00:00', '2019-11-09 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2019-11-09', 'end_date': '2019-11-10', 'weather_code': 64.0, 'temperature_2m_max': 27.75, 'temperature_2m_min': 23.7, 'temperature_2m_mean': 25.013542, 'precipitation_sum': 32.3, 'rain_sum': 32.3, 'wind_speed_10m_max': 20.57108, 'wind_gusts_10m_max': 50.399998, 'wind_direction_10m_dominant': 126.76021, 'shortwave_radiation_sum': 7.895}, {'date': DatetimeIndex(['2020-06-14 18:00:00+00:00', '2020-06-15 18:00:00+00:00',
#                '2020-06-16 18:00:00+00:00', '2020-06-17 18:00:00+00:00',
#                '2020-06-18 18:00:00+00:00', '2020-06-19 18:00:00+00:00',
#                '2020-06-20 18:00:00+00:00', '2020-06-21 18:00:00+00:00',
#                '2020-06-22 18:00:00+00:00', '2020-06-23 18:00:00+00:00',
#                ...
#                '2020-09-20 18:00:00+00:00', '2020-09-21 18:00:00+00:00',
#                '2020-09-22 18:00:00+00:00', '2020-09-23 18:00:00+00:00',
#                '2020-09-24 18:00:00+00:00', '2020-09-25 18:00:00+00:00',
#                '2020-09-26 18:00:00+00:00', '2020-09-27 18:00:00+00:00',
#                '2020-09-28 18:00:00+00:00', '2020-09-29 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=108, freq='D'), 'start_date': '2020-06-15', 'end_date': '2020-09-30', 'weather_code': 58.61111, 'temperature_2m_max': 29.86111, 'temperature_2m_min': 25.522684, 'temperature_2m_mean': 27.36009, 'precipitation_sum': 13.337964, 'rain_sum': 13.337964, 'wind_speed_10m_max': 17.813362, 'wind_gusts_10m_max': 36.506668, 'wind_direction_10m_dominant': 171.7444, 'shortwave_radiation_sum': 15.085557}, {'date': DatetimeIndex(['2020-05-19 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2020-05-20', 'end_date': '2020-05-20', 'weather_code': 53.0, 'temperature_2m_max': 33.5, 'temperature_2m_min': 25.8, 'temperature_2m_mean': 28.827085, 'precipitation_sum': 3.7999997, 'rain_sum': 3.7999997, 'wind_speed_10m_max': 33.043606, 'wind_gusts_10m_max': 73.439995, 'wind_direction_10m_dominant': 137.69788, 'shortwave_radiation_sum': 18.24}, {'date': DatetimeIndex(['2021-07-26 18:00:00+00:00', '2021-07-27 18:00:00+00:00',
#                '2021-07-28 18:00:00+00:00', '2021-07-29 18:00:00+00:00',
#                '2021-07-30 18:00:00+00:00', '2021-07-31 18:00:00+00:00',
#                '2021-08-01 18:00:00+00:00', '2021-08-02 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2021-07-27', 'end_date': '2021-08-03', 'weather_code': 63.25, 'temperature_2m_max': 28.09375, 'temperature_2m_min': 24.89375, 'temperature_2m_mean': 26.354427, 'precipitation_sum': 51.587498, 'rain_sum': 51.587498, 'wind_speed_10m_max': 21.650536, 'wind_gusts_10m_max': 42.39, 'wind_direction_10m_dominant': 165.72902, 'shortwave_radiation_sum': 9.751249}, {'date': DatetimeIndex(['2021-05-26 18:00:00+00:00'], dtype='datetime64[ns, UTC]', freq='D'), 'start_date': '2021-05-27', 'end_date': '2021-05-27', 'weather_code': 51.0, 'temperature_2m_max': 34.95, 'temperature_2m_min': 27.3, 'temperature_2m_mean': 30.141665, 'precipitation_sum': 0.5, 'rain_sum': 0.5, 'wind_speed_10m_max': 26.987997, 'wind_gusts_10m_max': 56.16, 'wind_direction_10m_dominant': 162.04994, 'shortwave_radiation_sum': 20.69}]

# %%
weather_data_df = pd.DataFrame(date_list)
weather_data_df.index.name = 'Row_Number'
print(weather_data_df)
# Out:
#                                                          date  start_date  \
# Row_Number
# 0           DatetimeIndex(['1941-05-20 18:00:00+00:00'], d...  1941-05-21
# 1           DatetimeIndex(['1947-10-20 18:00:00+00:00'], d...  1947-10-21
# 2           DatetimeIndex(['1958-10-19 18:00:00+00:00'], d...  1958-10-20
# 3           DatetimeIndex(['1960-10-08 18:00:00+00:00'], d...  1960-10-09
# 4           DatetimeIndex(['1960-10-29 18:00:00+00:00'], d...  1960-10-30
# ...                                                       ...         ...
# 252         DatetimeIndex(['2019-11-08 18:00:00+00:00', '2...  2019-11-09
# 253         DatetimeIndex(['2020-06-14 18:00:00+00:00', '2...  2020-06-15
# 254         DatetimeIndex(['2020-05-19 18:00:00+00:00'], d...  2020-05-20
# 255         DatetimeIndex(['2021-07-26 18:00:00+00:00', '2...  2021-07-27
# 256         DatetimeIndex(['2021-05-26 18:00:00+00:00'], d...  2021-05-27
#
#               end_date  weather_code  temperature_2m_max  temperature_2m_min  \
# Row_Number
# 0           1941-05-21     51.000000           29.549999           26.799999
# 1           1947-10-21      1.000000           28.350000           24.600000
# 2           1958-10-20     51.000000           29.549999           24.100000
# 3           1960-10-09     63.000000           27.650000           25.700001
# 4           1960-10-30     61.000000           28.900000           23.250000
# ...                ...           ...                 ...                 ...
# 252         2019-11-10     64.000000           27.750000           23.700001
# 253         2020-09-30     58.611111           29.861111           25.522684
# 254         2020-05-20     53.000000           33.500000           25.799999
# 255         2021-08-03     63.250000           28.093750           24.893749
# 256         2021-05-27     51.000000           34.950001           27.299999
#
#             temperature_2m_mean  precipitation_sum   rain_sum  \
# Row_Number
# 0                     28.243750           1.600000   1.600000
# 1                     26.481249           0.000000   0.000000
# 2                     26.766668           0.800000   0.800000
# 3                     26.587502          44.400002  44.400002
# 4                     25.699999           2.000000   2.000000
# ...                         ...                ...        ...
# 252                   25.013542          32.299999  32.299999
# 253                   27.360090          13.337964  13.337964
# 254                   28.827085           3.800000   3.800000
# 255                   26.354427          51.587498  51.587498
# 256                   30.141665           0.500000   0.500000
#
#             wind_speed_10m_max  wind_gusts_10m_max  \
# Row_Number
# 0                    13.320000           21.599998
# 1                    20.188908           29.160000
# 2                     9.832680           15.119999
# 3                    39.797504           55.079998
# 4                    15.745627           20.880001
# ...                        ...                 ...
# 252                  20.571079           50.399998
# 253                  17.813362           36.506668
# 254                  33.043606           73.439995
# 255                  21.650536           42.389999
# 256                  26.987997           56.160000
#
#             wind_direction_10m_dominant  shortwave_radiation_sum
# Row_Number
# 0                            260.712219                24.209999
# 1                              1.113367                20.719999
# 2                            104.604446                18.180000
# 3                            342.631531                 6.320000
# 4                             16.234982                16.969999
# ...                                 ...                      ...
# 252                          126.760208                 7.895000
# 253                          171.744400                15.085557
# 254                          137.697876                18.240000
# 255                          165.729019                 9.751249
# 256                          162.049942                20.690001
#
# [257 rows x 13 columns]

# %%
temp_disaster = pd.DataFrame(df_cleaned['Disaster Type'])
temp_disaster_reset = temp_disaster.reset_index(drop=True)
temp_disaster_reset.index.name = 'Row_Number'
temp_disaster_reset.rename(columns={None: 'disaster_type'}, inplace=True)
print(temp_disaster_reset)
# Out:
#            Disaster Type
# Row_Number
# 0                  Storm
# 1                  Storm
# 2                  Storm
# 3                  Storm
# 4                  Storm
# ...                  ...
# 252                Storm
# 253                Flood
# 254                Storm
# 255                Flood
# 256                Storm
#
# [257 rows x 1 columns]

# %%
combined_data = pd.merge(weather_data_df, temp_disaster_reset, on='Row_Number', how='inner')
print(combined_data)
# Out:
#                                                          date  start_date  \
# Row_Number
# 0           DatetimeIndex(['1941-05-20 18:00:00+00:00'], d...  1941-05-21
# 1           DatetimeIndex(['1947-10-20 18:00:00+00:00'], d...  1947-10-21
# 2           DatetimeIndex(['1958-10-19 18:00:00+00:00'], d...  1958-10-20
# 3           DatetimeIndex(['1960-10-08 18:00:00+00:00'], d...  1960-10-09
# 4           DatetimeIndex(['1960-10-29 18:00:00+00:00'], d...  1960-10-30
# ...                                                       ...         ...
# 252         DatetimeIndex(['2019-11-08 18:00:00+00:00', '2...  2019-11-09
# 253         DatetimeIndex(['2020-06-14 18:00:00+00:00', '2...  2020-06-15
# 254         DatetimeIndex(['2020-05-19 18:00:00+00:00'], d...  2020-05-20
# 255         DatetimeIndex(['2021-07-26 18:00:00+00:00', '2...  2021-07-27
# 256         DatetimeIndex(['2021-05-26 18:00:00+00:00'], d...  2021-05-27
#
#               end_date  weather_code  temperature_2m_max  temperature_2m_min  \
# Row_Number
# 0           1941-05-21     51.000000           29.549999           26.799999
# 1           1947-10-21      1.000000           28.350000           24.600000
# 2           1958-10-20     51.000000           29.549999           24.100000
# 3           1960-10-09     63.000000           27.650000           25.700001
# 4           1960-10-30     61.000000           28.900000           23.250000
# ...                ...           ...                 ...                 ...
# 252         2019-11-10     64.000000           27.750000           23.700001
# 253         2020-09-30     58.611111           29.861111           25.522684
# 254         2020-05-20     53.000000           33.500000           25.799999
# 255         2021-08-03     63.250000           28.093750           24.893749
# 256         2021-05-27     51.000000           34.950001           27.299999
#
#             temperature_2m_mean  precipitation_sum   rain_sum  \
# Row_Number
# 0                     28.243750           1.600000   1.600000
# 1                     26.481249           0.000000   0.000000
# 2                     26.766668           0.800000   0.800000
# 3                     26.587502          44.400002  44.400002
# 4                     25.699999           2.000000   2.000000
# ...                         ...                ...        ...
# 252                   25.013542          32.299999  32.299999
# 253                   27.360090          13.337964  13.337964
# 254                   28.827085           3.800000   3.800000
# 255                   26.354427          51.587498  51.587498
# 256                   30.141665           0.500000   0.500000
#
#             wind_speed_10m_max  wind_gusts_10m_max  \
# Row_Number
# 0                    13.320000           21.599998
# 1                    20.188908           29.160000
# 2                     9.832680           15.119999
# 3                    39.797504           55.079998
# 4                    15.745627           20.880001
# ...                        ...                 ...
# 252                  20.571079           50.399998
# 253                  17.813362           36.506668
# 254                  33.043606           73.439995
# 255                  21.650536           42.389999
# 256                  26.987997           56.160000
#
#             wind_direction_10m_dominant  shortwave_radiation_sum Disaster Type
# Row_Number
# 0                            260.712219                24.209999         Storm
# 1                              1.113367                20.719999         Storm
# 2                            104.604446                18.180000         Storm
# 3                            342.631531                 6.320000         Storm
# 4                             16.234982                16.969999         Storm
# ...                                 ...                      ...           ...
# 252                          126.760208                 7.895000         Storm
# 253                          171.744400                15.085557         Flood
# 254                          137.697876                18.240000         Storm
# 255                          165.729019                 9.751249         Flood
# 256                          162.049942                20.690001         Storm
#
# [257 rows x 14 columns]

# %%
combined_data.to_csv('combined_disaster_weather_data.csv', index=False)
